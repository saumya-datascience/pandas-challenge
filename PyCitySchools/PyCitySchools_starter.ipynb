# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()

#I think there is no reason use groupby, because in code are not count some values per groups.

#conditions = [
 #   ((df["Balance"]>0) & (df['Value']>0) & (df['L_Date']<=df['c_date'])),
  #  ((df["Balance"]==0) & (df['Value']==0) & (df['L_Date']<=df['c_date']))]
#choices = ['Good', 'Bad']
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
school_count=school_data_complete["School ID"].value_counts()
total_school=len(school_count)
print(total_school)

#Calculate the total number of students
total_students=school_data_complete["Student ID"].count()
print(total_students)

#Calculate the total budget
tot_budget=school_data["budget"].sum()
print(tot_budget)

#Calculate the average math score
avg_maths=school_data_complete["math_score"].mean()
print(avg_maths)

#avearge reading score
avg_reading=school_data_complete["reading_score"].mean()
print(avg_reading)

#calculate the percentage of students with a passing math score(70 or greater)
per_passmaths=(len(school_data_complete[school_data_complete.math_score >=70])/total_students)*100
print(per_passmaths)

#calculate the percentage of students with  passing reading score(70 or greater)
per_passread=(len(school_data_complete[school_data_complete.reading_score>=70])/total_students)*100
print(per_passread)

#Calculate the percentage of students who passed math and reading (% Overall Passing)
per_read_math=len(school_data_complete[(school_data_complete["reading_score"]>=70) & (school_data_complete["math_score"]>=70)])
percent_read_math=per_read_math/total_students*100
percent_read_math

district_df=pd.DataFrame({"Total Schools":total_school,
                         "Total Students":total_students,
                         "Total Budget":tot_budget,
                         "Average Math Score":avg_maths,
                         "Average Reading Score":avg_reading,
                         "% Passing Math":per_passmaths,
                         "% Passing Reading":per_passread,
                         "% Overall Passing":percent_read_math}, index=[0])
district_df
# Out:
# 15
# 39170
# 24649428
# 78.98537145774827
# 81.87784018381414
# 74.9808526933878
# 85.80546336482001
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#school name

school_info_df=school_data_complete.groupby("school_name")
name=school_info_df["school_name"].unique()
#School Type
name_type=school_info_df["type"].unique()
#total Students
total_student=school_info_df["Student ID"].count()
#total_School Budget
tot_budget=school_info_df["budget"].mean()
#Per Student Budget
per_school_counts = school_data_complete["school_name"].value_counts()
per_stu_budget=tot_budget/per_school_counts

#print(average_math)
average_math=school_info_df["math_score"].mean()
#Average reading score
average_reading=school_info_df["reading_score"].mean()
#print(pass_percent_maths)
school_passing_math = school_data_complete[(school_data_complete["math_score"] >= 70)]
pass_percent_maths=school_passing_math.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
#% passsing reading
school_passing_reading=school_data_complete[(school_data_complete["reading_score"]>=70)]
per_school_reading=school_passing_reading.groupby(["school_name"]).count()["student_name"]/per_school_count*100

#% overall passing
pass_reading_math=school_data_complete[(school_data_complete["reading_score"]>=70) & (school_data_complete["math_score"]>=70)]
Overall_Passing= pass_reading_math.groupby("school_name").count()["student_name"]/per_school_count*100

school_summary_df=pd.DataFrame({"School Type":name_type,
                      "Total School Budget":tot_budget,
                      "Total Students":total_student,
                      "Per Student Budget":per_stu_budget,
                      "Average Math Score":average_math,
                      "Average Reading Score":average_reading,
                      "% Passing Math":pass_percent_maths,
                      "% Passing Reading":per_school_reading,
                      "% Overall Passing":Overall_Passing})

school_summary_df

#data=[name_type,tot_budget,total_student,per_stu_budget,average_math,average_reading,pass_percent_maths,per_school_reading,Overall_Passing]

#headers=["School Type","Total School Budget","Total Students","Per Student Budget","Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"]
#df3 = pd.concat(data,axis=1,keys=headers)
#df3
# Out:
#                       School Type  Total School Budget  Total Students  \
# school_name
# Bailey High School     [District]              3124928            4976
# Cabrera High School     [Charter]              1081356            1858
# Figueroa High School   [District]              1884411            2949
# Ford High School       [District]              1763916            2739
# Griffin High School     [Charter]               917500            1468
# Hernandez High School  [District]              3022020            4635
# Holden High School      [Charter]               248087             427
# Huang High School      [District]              1910635            2917
# Johnson High School    [District]              3094650            4761
# Pena High School        [Charter]               585858             962
# Rodriguez High School  [District]              2547363            3999
# Shelton High School     [Charter]              1056600            1761
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
sorted_df=school_summary_df.sort_values("% Overall Passing", ascending=False)
sorted_df.head(5)
# Out:
#                     School Type  Total School Budget  Total Students  \
# school_name
# Cabrera High School   [Charter]              1081356            1858
# Thomas High School    [Charter]              1043130            1635
# Griffin High School   [Charter]               917500            1468
# Wilson High School    [Charter]              1319574            2283
# Pena High School      [Charter]               585858             962
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
worst_sorted_df=school_summary_df.sort_values("% Overall Passing")
worst_sorted_df.head(5)
# Out:
#                       School Type  Total School Budget  Total Students  \
# school_name
# Rodriguez High School  [District]              2547363            3999
# Figueroa High School   [District]              1884411            2949
# Huang High School      [District]              1910635            2917
# Hernandez High School  [District]              3022020            4635
# Johnson High School    [District]              3094650            4761
#
#                        Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
nineth_df = school_data_complete.loc[school_data_complete["grade"]=="9th",["school_name","math_score"]]
group_nine=nineth_df.groupby("school_name")["math_score"].mean()                              
group_nine.head()
tenth_df = school_data_complete.loc[school_data_complete["grade"]=="10th",["school_name","math_score"]]
group_ten=tenth_df.groupby("school_name")["math_score"].mean()                              
group_ten.head()
eleven_df = school_data_complete.loc[school_data_complete["grade"]=="11th",["school_name","math_score"]]
group_eleven=eleven_df.groupby("school_name")["math_score"].mean()                              
group_eleven.head()
twelve_df = school_data_complete.loc[school_data_complete["grade"]=="12th",["school_name","math_score"]]
group_twelve=twelve_df.groupby("school_name")["math_score"].mean()                              
group_twelve.head()
d=(group_nine,group_ten,group_eleven,group_twelve)
headers=["9th","10th","11th","12th"]
math=pd.concat(d,axis=1,keys=headers)
math.head()
#school_data_complete.groupby(['school_name','grade' as_index=False])['math_score'].mean()
# Out:
#                             9th       10th       11th       12th
# school_name
# Bailey High School    77.083676  76.996772  77.515588  76.492218
# Cabrera High School   83.094697  83.154506  82.765560  83.277487
# Figueroa High School  76.403037  76.539974  76.884344  77.151369
# Ford High School      77.361345  77.672316  76.918058  76.179963
# Griffin High School   82.044010  84.229064  83.842105  83.356164

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
nineth_df = school_data_complete.loc[school_data_complete["grade"]=="9th",["school_name","reading_score"]]
group_nine=nineth_df.groupby("school_name")["reading_score"].mean()                              
tenth_df = school_data_complete.loc[school_data_complete["grade"]=="10th",["school_name","reading_score"]]
group_ten=tenth_df.groupby("school_name")["reading_score"].mean()                              
#group_ten.head()
eleven_df = school_data_complete.loc[school_data_complete["grade"]=="11th",["school_name","reading_score"]]
group_eleven=eleven_df.groupby("school_name")["reading_score"].mean()                              
#group_eleven.head()
twelve_df = school_data_complete.loc[school_data_complete["grade"]=="12th",["school_name","reading_score"]]
group_twelve=twelve_df.groupby("school_name")["reading_score"].mean()                              
#group_twelve.head()
f=(group_nine,group_ten,group_eleven,group_twelve)
headers=["9th","10th","11th","12th"]
reading=pd.concat(f,axis=1,keys=headers)
reading.head()
# Out:
#                             9th       10th       11th       12th
# school_name
# Bailey High School    81.303155  80.907183  80.945643  80.912451
# Cabrera High School   83.676136  84.253219  83.788382  84.287958
# Figueroa High School  81.198598  81.408912  80.640339  81.384863
# Ford High School      80.632653  81.262712  80.403642  80.662338
# Griffin High School   83.369193  83.706897  84.288089  84.013699

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#min_value=school_summary_df["Per Student Budget"].min()

hp_bins = [0,585, 630, 645,680]
hp_labels = ["<585", "$585-630", "$630-645","$645-680"]

# Bin the Horsepower column
# cut() returns a Pandas Series containing each of the binned column's values translated into their corresponding bins

school_summary_df["spending_ranges"]=pd.cut(school_summary_df["Per Student Budget"], hp_bins, labels=hp_labels)
df3.head()
spending_ranges=school_summary_df.groupby(["spending_ranges"])["Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"].mean()
spending_ranges.head()
# Out:
# C:\Users\Saumy\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   # This is added back by InteractiveShellApp.init_path()
#                  Average Math Score  Average Reading Score  % Passing Math  \
# spending_ranges
# <585                      83.455399              83.933814       93.460096
# $585-630                  81.899826              83.155286       87.133538
# $630-645                  78.518855              81.624473       73.484209
# $645-680                  76.997210              81.027843       66.164813
#
#                  % Passing Reading  % Overall Passing
# spending_ranges
# <585                     96.610877          90.369459
# $585-630                 92.718205          81.418596
# $630-645                 84.391793          62.857656
# $645-680                 81.133951          53.526855

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
ss_bins=[0,1000,2000,5000]
ss_labels=["Small (<1000)","Medium (1000-2000)","Large (2000-5000)"]
school_summary_df["School Size"]=pd.cut(school_summary_df["Total Students"],ss_bins,labels=ss_labels)
school_size=school_summary_df.groupby("School Size")["Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"].mean()
school_size.head()
school_summary_df.head()
#school_sizeschool_size.groupby("total Students")
# Out:
# C:\Users\Saumy\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
#                      School Type  Total School Budget  Total Students  \
# school_name
# Bailey High School    [District]              3124928            4976
# Cabrera High School    [Charter]              1081356            1858
# Figueroa High School  [District]              1884411            2949
# Ford High School      [District]              1763916            2739
# Griffin High School    [Charter]               917500            1468
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
Math_df=school_summary_df.groupby(["School Type"]).mean()["Average Math Score"]
Math_df



#["Average Math Score","Average Reading Score","% Passing Math","% Passing Reading","% Overall Passing"].mean()
#school_type.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-7573efbf6c05> in <module>
# ----> 1 Math_df=school_summary_df.groupby(["School Type"]).mean()["Average Math Score"]
#       2 Math_df
#       3
#       4
#       5
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1224         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1225         return self._cython_agg_general(
# -> 1226             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1227         )
#    1228
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     992     ) -> DataFrame:
#     993         agg_blocks, agg_items = self._cython_agg_blocks(
# ...
